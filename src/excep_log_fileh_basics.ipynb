# %% [markdown]
# ### Exceptions
#
# If things go wrong during the execution of the program(runtime). It generally happens when something unforeseen has happened.
#
# - Exceptions are raised by python runtime
# - You have to takle is on the fly
#
# #### **Examples**
#
# - Memory overflow
# - Divide by 0 -> logical error
# - Database error

# %% [markdown]
# # Why is it important to handle exceptions
# 1 . User experience (Mind fuck> error message)
# 2 . Security (shows the code when error is shown)
#
# # How to handle exceptions
# -> Try except block

# %% [markdown]
# ### EXCEPTION CLASS -> SUPERCLASS
# ### all others are sub class the errors

# %% [markdown]
#  ### Raise Exception
#  In Python programming, exceptions are raised when errors occur at runtime.
#  We can also manually raise exceptions using the raise keyword.
#
# We can optionally pass values to the exception to clarify why that exception was raised

# %%
# try catch demo
try:
  f= open('sample1.txt','r') 
  print(f.read())
except FileNotFoundError:
    print('sorry file not found')
    
except Exception as e :
    print(e)
# Out:
# sorry file not found

# %%
# finally
# else
try:
  f = open('sample1.txt','r')
except FileNotFoundError:
  print('file nai mili')
except Exception:
  print('kuch to lafda hai')
else:
  print(f.read())
finally:
  print('ye to print hoga hi')
# Out:
# file nai mili
# ye to print hoga hi

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### In Python>
# ~~~~
# 1.Syntax Error
# 2.Logical Error

# %% [markdown]
# ~~~
# Syntax >> how you write code (indentation)
# ~~~
# Logical >> Exceptions (occurs during runtime)

# %%
print(dir(locals()["__builtins__"]))
#buildin exceptions
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxW
# ...

# %% [markdown]
# ##### If the error does not belong to any category it will give "RunTimeError"
# we have <<<<try, except, finally, else>>>>

# %% [markdown]
# ~~~
# When error Occurs except block gets executed

# %%
l=[1,2,3,4,6]

try:
    for i in range(len(l)+1):
        print(l[i])
        
except:
    print("Out of range")
# Out:
# 1
# 2
# 3
# 4
# 6
# Out of range

# %%
import sys

randomList=['a',0,2]

for entry in randomList:
    
               
    try:
        print("The entry is",entry)
        r=1/int(entry)
        break
    except:
        print("oops",sys.exc_info()[0],"occured") # to get the info about the exception(like exception e)
        print("next entry")
        
        

        
print("The reciprocal of",entry,"is",r)
# Out:
# The entry is a
# oops <class 'ValueError'> occured
# next entry
# The entry is 0
# oops <class 'ZeroDivisionError'> occured
# next entry
# The entry is 2
# The reciprocal of 2 is 0.5

# %%
# try:
    # block of code
# except Exceptions:
    # block of code
# else:
    #this code excecutes when exception not occured

# %%
pwd()
# Out:
# 'c:\\Users\\spand\\Desktop\\end to end\\project_life_cycle\\src'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 28FC-998A
#
#  Directory of c:\Users\spand\Desktop\end to end\project_life_cycle\src
#
# 04/18/2023  04:53 PM    <DIR>          .
# 04/18/2023  04:28 PM    <DIR>          ..
# 04/17/2023  04:55 PM                 0 __init__.py
# 04/17/2023  05:04 PM    <DIR>          components
# 04/18/2023  04:26 PM               897 exception.py
# 04/19/2023  01:03 AM            63,382 exception_basics.ipynb
# 04/18/2023  03:04 PM               425 logger.py
# 04/17/2023  05:05 PM    <DIR>          pipeline
# 04/18/2023  03:04 PM             1,564 utils.py
#                5 File(s)         66,268 bytes
#                4 Dir(s)  219,432,497,152 bytes free

# %%
#FILE HANDLING
# r open a filefor readding
# w opens a file for writing and creates a new file if its does not exits or tructaes the file if exitss
# x opens a file for exclustive creation if the file already exits operations
# a open a file for appending at ethe ned of file
# + oepns a file for updating (reading and writing)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Iterator and Generator

# %%
#### itertables are not iterators
#### iterator are also interables
#### calling iter() function on iterable gives an iterator
#### calling next() function on iterator gives next elements

# %%
#Generator are other way of creating iterator

# %%
#Application is BlackBox(functions in the program) to Moniter the application we need Logging 
#Logging is a Module in python
# moniter and track

# %%
#The __init__.py file is executed when the package is imported and can contain initialization code for the package.

# %% [markdown]
# ####  a module is a single file containing Python code, while a package is a collection of modules organized in a directory hierarchy.
# ![image.png](attachment:image.png)

# %%
#Types of logs
# DEBUG (trying to find bug)
# INFO (just info)
# WARNING (just a warning msg)
# ERROR (top priority)code has crashed
# CRITICAL
